# %% [markdown]
# # Synthetic Data Generation using NVIDIA's APIs
# <table>
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/drive/1Qc9ehY8ykmZPmxP0JH4HHmGkUTG6oMax?usp=sharing">
#       <img src="https://cloud.google.com/ml-engine/images/colab-logo-32px.png" alt="Google Colaboratory logo"><br> Run in Colab
#     </a>
#   </td>
# </table>

# %%
# !pip install openai langchain
# !pip install --upgrade --quiet langchain-nvidia-ai-endpoints
# !pip install langchain_experimental
# !pip install langchain_nvidia_ai_endpoints
# Out:
# Collecting openai
#   Downloading openai-1.51.0-py3-none-any.whl.metadata (24 kB)
# Collecting langchain
#   Downloading langchain-0.3.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.8)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.4.0,>=0.3.8 (from langchain)
#   Downloading langchain_core-0.3.9-py3-none-any.whl.metadata (6.3 kB)
# Collecting langchain-text-splitters<0.4.0,>=0.3.0 (from langchain)
#   Downloading langchain_text_splitters-0.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.131-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Collecting tenacity!=8.4.0,<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.13.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.4.0,>=0.3.8->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.8->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.5 MB/s eta 0:00:00
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.8->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Downloading openai-1.51.0-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.5/383.5 kB 9.7 MB/s eta 0:00:00
# Downloading langchain-0.3.2-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.2 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 4.8 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 13.9 MB/s eta 0:00:00
# Downloading langchain_core-0.3.9-py3-none-any.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.8/401.8 kB 19.0 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.0-py3-none-any.whl (25 kB)
# Downloading langsmith-0.1.131-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 15.4 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading orjson-3.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.5 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.6 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: tenacity, orjson, jsonpointer, jiter, h11, requests-toolbelt, jsonpatch, httpcore, httpx, openai, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# Successfully installed h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 jiter-0.5.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.2 langchain-core-0.3.9 langchain-text-splitters-0.3.0 langsmith-0.1.131 openai-1.51.0 orjson-3.10.7 requests-toolbelt-1.0.0 tenacity-8.5.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 1.3 MB/s eta 0:00:00
# Collecting langchain_experimental
#   Downloading langchain_experimental-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting langchain-community<0.4.0,>=0.3.0 (from langchain_experimental)
#   Downloading langchain_community-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain_experimental) (0.3.9)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.8)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community<0.4.0,>=0.3.0->langchain_experimental)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.1.131)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.26.4)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community<0.4.0,>=0.3.0->langchain_experimental)
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain_experimental) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain_experimental) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental)
#   Downloading marshmallow-3.22.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.1->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.6->langchain_experimental) (2.23.4)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain_experimental)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (0.14.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain_experimental)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain_experimental) (1.2.2)
# Downloading langchain_experimental-0.3.2-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 5.1 MB/s eta 0:00:00
# Downloading langchain_community-0.3.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.7 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading marshmallow-3.22.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, typing-inspect, pydantic-settings, dataclasses-json, langchain-community, langchain_experimental
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.3.1 langchain_experimental-0.3.2 marshmallow-3.22.0 mypy-extensions-1.0.0 pydantic-settings-2.5.2 python-dotenv-1.0.1 typing-inspect-0.9.0
# Requirement already satisfied: langchain_nvidia_ai_endpoints in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from langchain_nvidia_ai_endpoints) (3.10.8)
# Requirement already satisfied: langchain-core<0.4,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain_nvidia_ai_endpoints) (0.3.9)
# Requirement already satisfied: pillow<11.0.0,>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain_nvidia_ai_endpoints) (10.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (1.13.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (4.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (0.1.131)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (2.9.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (4.12.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (2.23.4)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.9.1->langchain_nvidia_ai_endpoints) (3.10)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (2.2.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-core<0.4,>=0.3.0->langchain_nvidia_ai_endpoints) (1.2.2)

# %%
from langchain.prompts import FewShotPromptTemplate, PromptTemplate
from langchain.chat_models import ChatOpenAI
from pydantic import BaseModel
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_experimental.tabular_synthetic_data.base import SyntheticDataGenerator
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator, OPENAI_TEMPLATE
from langchain_experimental.tabular_synthetic_data.prompts import SYNTHETIC_FEW_SHOT_SUFFIX, SYNTHETIC_FEW_SHOT_PREFIX

# %%
# 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
# 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

# %% [markdown]
# **Use Nvidia API Keys provided you in mail or you can create by logging into** [Build Nvidia](https://build.nvidia.com/)

# %%
import getpass
import os

if not os.getenv("NVIDIA_API_KEY"):
    # Note: the API key should start with "nvapi-"
    os.environ["NVIDIA_API_KEY"] = getpass.getpass("Enter your NVIDIA API key: ")
# Out:
# Enter your NVIDIA API key: ··········

# %% [markdown]
# you can download csv files by this [link](https://drive.google.com/file/d/19eTFRj2ctWYOmdYHuC7h7qlBBDYqSVVM/view) , upload into your drive and connect with colab.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Data Cleaning and Preprocessing**

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/product_asin.csv',encoding="ISO-8859-1",on_bad_lines='skip')
dataset.head()
# Out:
#     X                                              title parent_asin  \
# 0   1                     Allegra Allergy 45ct + 15 Free  B00JENH5OI
# 1   2  InvoSpa Shiatsu Back Shoulder and Neck Massage...  B0C4L5Y711
# 2   4  Kal 100 Mcg Selenium Yeast Free Tablets, 100 C...  B00020HX5S
# 3   5  Rocky Mountain Oils Cinnamon Bark Essential Oi...  B07K363N3S
# 4  12  Prevail Super Absorbent Underpads, Prevail Sup...  B00ACMDOOA
#
#               categories                      cat1  \
# 0  ['Health & Household'             'Health Care'
# 1  ['Health & Household'   'Wellness & Relaxation'
# 2  ['Health & Household'                 'Vitamins
# 3  ['Health & Household'             'Health Care'
# 4  ['Health & Household'             'Health Care'
#
#                              cat2                               cat3  \
# 0   'Over-the-Counter Medication'                           'Allergy
# 1     'Massage Tools & Equipment'               'Electric Massagers'
# 2         Minerals & Supplements'                         'Vitamins'
# 3          'Alternative Medicine'                    'Aromatherapy']
# 4         'Incontinence & Ostomy'   'Protective Briefs & Underwear']
#
#                  cat4                  cat5 cat6
# 0     Sinus & Asthma'   'Allergy Medicine']  NaN
# 1   'Back Massagers']                   NaN  NaN
# 2    'Multivitamins']                   NaN  NaN
# 3                 NaN                   NaN  NaN
# 4                 NaN                   NaN  NaN

# %%
dataset.dtypes
# Out:
# X               int64
# title          object
# parent_asin    object
# categories     object
# cat1           object
# cat2           object
# cat3           object
# cat4           object
# cat5           object
# cat6           object
# dtype: object

# %%
dataset['categories'] = dataset['categories'].str.replace(r"[\[\]']", "", regex=True)
dataset['categories']
# Out:
# 0         Health & Household
# 1         Health & Household
# 2         Health & Household
# 3         Health & Household
# 4         Health & Household
#                  ...
# 482980    Health & Household
# 482981    Health & Household
# 482982    Health & Household
# 482983    Health & Household
# 482984    Health & Household
# Name: categories, Length: 482985, dtype: object

# %%
dataset['cat1'] = dataset['cat1'].str.replace(r"[\[\]']", "", regex=True)
dataset['cat1']
# Out:
# 0                           Health Care
# 1                 Wellness & Relaxation
# 2                              Vitamins
# 3                           Health Care
# 4                           Health Care
#                       ...
# 482980            Wellness & Relaxation
# 482981          Diet & Sports Nutrition
# 482982     Medical Supplies & Equipment
# 482983     Medical Supplies & Equipment
# 482984                      Health Care
# Name: cat1, Length: 482985, dtype: object

# %%
dataset.tail(30)
# Out:
#              X                                              title parent_asin  \
# 482955  797513    Dynarex Gauze Sponge 2"x 2" 12 Ply. Pack of 200  B00QH9WGWS
# 482956  797514                      Best Naturals MSM Powder 4 OZ  B01CO8SLLA
# 482957  797515               Max Load - 2 caps,(M.D. Science Lab)  B001QZ94S2
# 482958  797516  ULCERx 10-15 mmHg Underliner Size: Large Long ...  B004LNHJBK
# 482959  797517  KuToo Replacement for Gear S3 Band, 22mm Gear ...  B079868YZW
# 482960  797518  Hopgo Ankle Brace for Women Men, Foot Sleeve A...  B08JQ36YZM
# 482961  797521  TPS Professional Deep Tissue Massage Gun Relax...  B0881YY8YW
# 482980  Health & Household          Wellness & Relaxation
# 482981  Health & Household        Diet & Sports Nutrition
# 482982  Health & Household   Medical Supplies & Equipment
# 482983  Health & Household   Medical Supplies & Equipment
# 482984  Health & Household                    Health Care
#
#                                      cat2  \
# 482955                        'First Aid'
# 482956            Minerals & Supplements'
# 482957            Minerals & Supplements'
# 482958                            'Braces
# 482959                                NaN
# 482960                            'Braces
# 482961        'Massage Tools & Equipment'
# 482962     'Fitness & Activity Monitors']
# 482963   'Cloth Face Masks & Accessories'
# 482964                            'Braces
# 482965            Minerals & Supplements'
# 482966                            'Braces
# 482967                        'First Aid'
# 482968        'Massage Tools & Equipment'
# 482969        'Massage Tools & Equipment'
# 482970          'Nutrition Bars & Drinks'
# 482971            Minerals & Supplements'
# 482972                  'Sleep & Snoring'
# 482973            Minerals & Supplements'
# 482974                                NaN
# 482975             'Alternative Medicine'
# 482976                      'Foot Health'
# 482977      'Over-the-Counter Medication'
# 482978        'Massage Tools & Equipment'
# 482979            Minerals & Supplements'
# 482980       'Massage Tools & Equipment']
# 482981                     'Weight Loss']
# 482982                            'Braces
# 482983                  'Health Monitors'
# 482984      'Over-the-Counter Medication'
#
#                                              cat3  \
# 482955            'Bandages & Bandaging Supplies'
# 482956                                     'MSM']
# 482957                      'Herbal Supplements']
# 482958                       Splints & Supports']
# 482959                                        NaN
# 482960                        Splints & Supports'
# 482961                       'Electric Massagers'
# 482962                                        NaN
# 482963                        'Cloth Face Masks']
# 482964                        Splints & Supports'
# 482965                    'Essential Fatty Acids'
# 482966                        Splints & Supports'
# 482967            'Bandages & Bandaging Supplies'
# 482968                            'Massage Oils']
# 482969                       'Electric Massagers'
# 482970                           'Nutrition Bars'
# 482971                       'Sleep Supplements']
# 482972                          'Sleeping Masks']
# 482973   'Blended Vitamin & Mineral Supplements']
# 482974                                        NaN
# 482975                          'Oxygen Therapy']
# 482976                        'Inserts & Insoles'
# 482977                           'Pain Relievers'
# 482978                       'Electric Massagers'
# 482979                    'Essential Fatty Acids'
# 482980                                        NaN
# 482981                                        NaN
# 482982                        Splints & Supports'
# 482983                       'Body Weight Scales'
# 482984                             'Cough & Cold'
#
#                                cat4                        cat5  \
# 482955               'Gauze & Pads'                    'Gauze']
# 482956                          NaN                         NaN
# 482957                          NaN                         NaN
# 482958                          NaN                         NaN
# 482959                          NaN                         NaN
# 482960        'Leg & Foot Supports'            'Foot Supports']
# 482961            'Back Massagers']                         NaN
# 482962                          NaN                         NaN
# 482963                          NaN                         NaN
# 482964                        'Back   Neck & Shoulder Supports'
# 482965                 'Omega Oils'                  'Omega-3']
# 482966        'Leg & Foot Supports'              'Knee Braces']
# 482967               'Gauze & Pads'           'Bandaging Pads']
# 482968                          NaN                         NaN
# 482969            'Back Massagers']                         NaN
# 482970              'Protein Bars']                         NaN
# 482971                          NaN                         NaN
# 482972                          NaN                         NaN
# 482973                          NaN                         NaN
# 482974                          NaN                         NaN
# 482975                          NaN                         NaN
# 482976                   'Insoles']                         NaN
# 482977   'Alternative Pain Relief']                         NaN
# 482978            'Back Massagers']                         NaN
# 482979                 'Omega Oils'                  'Omega-3']
# 482980                          NaN                         NaN
# 482981                          NaN                         NaN
# 482982                        'Back   Neck & Shoulder Supports'
# 482983                   'Digital']                         NaN
# 482984         'Cold & Flu Relief']                         NaN
#
#                        cat6
# 482955                  NaN
# 482956                  NaN
# 482957                  NaN
# 482958                  NaN
# 482959                  NaN
# 482960                  NaN
# 482961                  NaN
# 482962                  NaN
# 482963                  NaN
# 482964       'Back Braces']
# 482965                  NaN
# 482966                  NaN
# 482967                  NaN
# 482968                  NaN
# 482969                  NaN
# 482970                  NaN
# 482971                  NaN
# 482972                  NaN
# 482973                  NaN
# 482974                  NaN
# 482975                  NaN
# 482976                  NaN
# 482977                  NaN
# 482978                  NaN
# 482979                  NaN
# 482980                  NaN
# 482981                  NaN
# 482982   'Lumbar Supports']
# 482983                  NaN
# 482984                  NaN

# %%
dataset = dataset.drop('cat6', axis=1)

# %%
dataset['cat2'] = dataset['cat2'].str.replace(r"[\[\]']", "", regex=True)
dataset['cat3'] = dataset['cat3'].str.replace(r"[\[\]']", "", regex=True)
dataset['cat4'] = dataset['cat4'].str.replace(r"[\[\]']", "", regex=True)
dataset['cat5'] = dataset['cat5'].str.replace(r"[\[\]']", "", regex=True)
dataset.head(10)
# Out:
#     X                                              title parent_asin  \
# 0   1                     Allegra Allergy 45ct + 15 Free  B00JENH5OI
# 1   2  InvoSpa Shiatsu Back Shoulder and Neck Massage...  B0C4L5Y711
# 2   4  Kal 100 Mcg Selenium Yeast Free Tablets, 100 C...  B00020HX5S
# 3   5  Rocky Mountain Oils Cinnamon Bark Essential Oi...  B07K363N3S
# 4  12  Prevail Super Absorbent Underpads, Prevail Sup...  B00ACMDOOA
# 5  15  Life Extension Bio-Curcumin Elite 400 mg 60 Ve...  B01LYS06EF
# 6  18  Contour Flip Pillow - 10-in-1 Rest Positions W...  B0C5JWD7FR
# 7  20  DAWGS Women's Loudmouth Patterns Z Sandals | L...  B00VMGV2DK
# 8  21  Optimum Nutrition Amino Energy Naturally Flavo...  B074K5KR9K
# 9  23  Analgesic Balm Counterpain Methyl Salicylate M...  B009NBVZGK
#
#            categories                           cat1  \
# 0  Health & Household                    Health Care
# 1  Health & Household          Wellness & Relaxation
# 2  Health & Household                       Vitamins
# 3  Health & Household                    Health Care
# 4  Health & Household                    Health Care
# 5  Health & Household                       Vitamins
# 6  Health & Household   Medical Supplies & Equipment
# 7  Health & Household                    Health Care
# 8  Health & Household        Diet & Sports Nutrition
# 9  Health & Household                    Health Care
#
#                             cat2                            cat3  \
# 0    Over-the-Counter Medication                         Allergy
# 1      Massage Tools & Equipment              Electric Massagers
# 2         Minerals & Supplements                        Vitamins
# 3           Alternative Medicine                    Aromatherapy
# 4          Incontinence & Ostomy   Protective Briefs & Underwear
# 5         Minerals & Supplements              Herbal Supplements
# 6   Mobility & Daily Living Aids      Bedroom Aids & Accessories
# 7                    Foot Health               Inserts & Insoles
# 8             Endurance & Energy                         Powders
# 9    Over-the-Counter Medication                  Pain Relievers
#
#                          cat4               cat5
# 0              Sinus & Asthma   Allergy Medicine
# 1              Back Massagers                NaN
# 2               Multivitamins                NaN
# 3                         NaN                NaN
# 4                         NaN                NaN
# 5                    Curcumin                NaN
# 6   Contoured Support Pillows                NaN
# 7                     Insoles                NaN
# 8                         NaN                NaN
# 9                         NaN                NaN

# %%
dataset = dataset.drop('X', axis=1)

# %%
reviews = pd.read_csv('/content/drive/MyDrive/reviews_supplements.csv',encoding="ISO-8859-1",on_bad_lines='skip')
reviews.head()
# Out:
#    rating                                title  \
# 0       4            B Complex in gel cap form
# 1       5                           Five Stars
# 2       5                           Five Stars
# 3       5         Vitamin Shoppe Dry Vitamin A
# 4       5  Un producto que compro regularmente
#
#                                                 text        asin parent_asin  \
# 0  I bought this along with Vit C in gel cap form...  B00012ND5G  B00012ND5G
# 1                                      great product  B00013Z0ZQ  B00013Z0ZQ
# 2                                 Came as expectedly  B00013Z0ZQ  B00013Z0ZQ
# 3  Excellent Product ..... Fast Delivery ....... ...  B00013Z1KA  B00013Z1KA
# 4                              Es muy buena vitamina  B00013Z1KA  B00013Z1KA
#
#                         user_id        timestamp  helpful_vote  \
# 0  AGDVFFLJWAQ3ULNNKF4LXID2RVSQ  12/11/2009 0:37             1
# 1  AG3BSKXHDGP6E3EGQD2SXCK6KFQQ    1/4/2015 3:11             0
# 2  AHG2WKFD4LXPC46WWC6JMQGX52JA  9/27/2015 19:15             0
# 3  AEOF7RT3AC4ACRX5HGIP2V3BNIHA          33:16.9             0
# 4  AGW2WETWQRL2PKUGTL2LU7IJ2BPQ          11:10.9             0
#
#    verified_purchase        date   time
# 0               True  12/11/2009   0:37
# 1               True    1/4/2015   3:11
# 2               True   9/27/2015  19:15
# 3               True    2/9/2019  19:33
# 4               True   7/25/2022  14:11

# %%
reviews.dtypes
# Out:
# rating                int64
# title                object
# text                 object
# asin                 object
# parent_asin          object
# user_id              object
# timestamp            object
# helpful_vote          int64
# verified_purchase      bool
# date                 object
# time                 object
# dtype: object

# %%
reviews = reviews.drop('timestamp', axis=1)

# %%
reviews['date'] = pd.to_datetime(reviews['date'],format= '%m/%d/%Y')
reviews['time'] = pd.to_datetime(reviews['time'],format= '%H:%M').dt.time

# %%
reviews.tail(20)
# Out:
#        rating                                              title  \
# 16651       4                    GOOD BUT NOT PURE VITAMIN E GEL
# 16652       5                                       Good product
# 16653       5                                      Vitamin E gel
# 16654       5                                   Husband loves it
# 16655       4               Safe, highly recommended product....
# 16656       5                       The best natural moisturizer
# 16657       3                                             Sticky
# 16658       5  Fruit of the Earth Vitamin-E gel has great soo...
# 16659       1                                 Broke my face out.
# 16660       5                                      Great service
# 16661       5                                          fantastic
# 16662       5                                   BEST LOTION EVER
# 16663       3    Top of cap was broken on arrival, causing leak.
# 16664       4                        Works wonders after surgery
# 16665       5                                         good stuff
# 16666       5                                              Love!
# 16667       5                                  Used to use this!
# 16668       5                                        works great
# 16669       4          That this product is unbelievably perfect
# 16670       5                                         Other uses
#
# 16669  B0C7RQ35K7  AECDMI6JKOAPXNCYCWSKQQPEO6YQ             0
# 16670  B0C7RQ35K7  AEHWPGRE2DYRGUKJPNFFJBYKNUPQ             2
#
#        verified_purchase       date      time
# 16651               True 2021-12-10  16:38:00
# 16652               True 2021-12-29  19:17:00
# 16653               True 2022-01-05  01:08:00
# 16654               True 2022-02-17  18:52:00
# 16655               True 2022-02-20  13:00:00
# 16656               True 2022-03-03  06:13:00
# 16657               True 2022-03-14  06:00:00
# 16658               True 2022-03-15  20:56:00
# 16659               True 2022-03-31  18:09:00
# 16660               True 2022-05-30  06:08:00
# 16661               True 2022-06-15  22:38:00
# 16662               True 2022-06-24  19:57:00
# 16663               True 2022-07-01  06:33:00
# 16664               True 2022-07-06  18:08:00
# 16665               True 2022-09-23  22:14:00
# 16666               True 2022-10-26  12:23:00
# 16667               True 2022-12-01  16:21:00
# 16668               True 2023-01-11  19:46:00
# 16669               True 2023-03-17  11:19:00
# 16670               True 2023-07-03  03:25:00

# %%
df = pd.merge(dataset, reviews, on='parent_asin', how='inner')
df.head(5)
# Out:
#                                              title_x parent_asin  \
# 0  Bariatric Fusion Bariatric Multivitamin Soft C...  B0BKC2WYWB
# 1  Bariatric Fusion Bariatric Multivitamin Soft C...  B0BKC2WYWB
# 2  Bariatric Fusion Bariatric Multivitamin Soft C...  B0BKC2WYWB
# 3  Bariatric Fusion Bariatric Multivitamin Soft C...  B0BKC2WYWB
# 4  Bariatric Fusion Bariatric Multivitamin Soft C...  B0BKC2WYWB
#
#            categories                 cat1 cat2 cat3 cat4 cat5  rating  \
# 0  Health & Household   Heart Health Event  NaN  NaN  NaN  NaN       5
# 1  Health & Household   Heart Health Event  NaN  NaN  NaN  NaN       1
# 2  Health & Household   Heart Health Event  NaN  NaN  NaN  NaN       5
# 3  Health & Household   Heart Health Event  NaN  NaN  NaN  NaN       5
# 4  Health & Household   Heart Health Event  NaN  NaN  NaN  NaN       3
#
#                      title_y  \
# 0              Good vitamins
# 1            Taste terrible!
# 2  Good alternative to pills
# 3  Certainly a good purchase
# 4           Not tasty at all
#
#                                                 text        asin  \
# 0  Is a bariatric patient, my vitamins are really...  B07JH63HWS
# 1  Not only did it taste terrible with a horrible...  B07JGTMK2L
# 2  Good flavor and no artificial sweeteners, whic...  B07JGFHQ5P
# 3  so Bariatric Fusion has multiple flavors and q...  B08HG44W98
# 4  This looked like one of the best bariatric vit...  B07JH63HWS
#
#                         user_id  helpful_vote  verified_purchase       date  \
# 0  AF2HY3SCRK45T2ATV7FKRYUJCCTA             0               True 2019-12-12
# 1  AEW6J6HI2GG7WWJSS77H6LXW3MYA             0               True 2020-04-02
# 2  AEOSYG7MLFUOIQXBSJ7UBZZBOTWQ             0               True 2020-08-22
# 3  AGPAXVLELK72U4USTT4LJ2JSG47Q             4               True 2020-10-17
# 4  AH73KJX7VIFLXKRLC6TLB7F3Z2VQ             0               True 2020-12-31
#
#        time
# 0  12:43:00
# 1  02:18:00
# 2  03:47:00
# 3  21:21:00
# 4  23:52:00

# %%
len(df)
# Out:
# 16663

# %%
df.to_csv('amazon_product_reviews.csv', index=False)

# %% [markdown]
# **Converting my dataframe to list of dictionaries for Few Shot Prompt template**

# %%
df = df.head(20)

# %%
# Converting the DataFrame to a list of dictionaries
examples = df.to_dict(orient='records')

# %%
examples[0]
# Out:
# {'title_x': 'Bariatric Fusion Bariatric Multivitamin Soft Chew | Tropical Fruit Flavor | Chewy for Post Bariatric Surgery Patients Including Gastric Bypass and Sleeve Gastrectomy | 60 Count | 1 Month Supply',
#  'parent_asin': 'B0BKC2WYWB',
#  'categories': 'Health & Household',
#  'cat1': ' Heart Health Event',
#  'cat2': nan,
#  'cat3': nan,
#  'cat4': nan,
#  'cat5': nan,
#  'rating': 5,
#  'title_y': 'Good vitamins',
#  'text': 'Is a bariatric patient, my vitamins are really important!! These Taste pretty good and seems to work.',
#  'asin': 'B07JH63HWS',
#  'user_id': 'AF2HY3SCRK45T2ATV7FKRYUJCCTA',
#  'helpful_vote': 0,
#  'verified_purchase': True,
#  'date': Timestamp('2019-12-12 00:00:00'),
#  'time': datetime.time(12, 43)}

# %% [markdown]
# # **Creating Prompt Template**

# %%
template_str = """
Product Review:
- Product Title: {title_x}
- Parent ASIN: {parent_asin}
- Categories: {categories}
- Sub-Category 1: {cat1}
- Sub-Category 2: {cat2}
- Sub-Category 3: {cat3}
- Sub-Category 4: {cat4}
- Sub-Category 5: {cat5}
- Rating: {rating}/5
- Review Title: {title_y}
- Review Text: "{text}"
- Product ASIN: {asin}
- User ID: {user_id}
- Helpful Votes: {helpful_vote}
- Verified Purchase: {verified_purchase}
- Review Date: {date}
- Review Time: {time}
"""

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain.prompts import PromptTemplate, FewShotPromptTemplate
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator
from langchain.output_parsers import PydanticOutputParser
from langchain_experimental.tabular_synthetic_data.prompts import SYNTHETIC_FEW_SHOT_SUFFIX, SYNTHETIC_FEW_SHOT_PREFIX
from pydantic import BaseModel

# %%
# Template for the synthetic data example
SYNTHETIC_DATA_EXAMPLE = PromptTemplate(
    input_variables=["title_x", "parent_asin", "categories", "cat1", "cat2", "cat3", "cat4", "cat5", "rating", "title_y", "text", "asin", "user_id", "helpful_vote", "verified_purchase", "date", "time"],
    template=template_str
)

prompt_template = FewShotPromptTemplate(
    prefix=SYNTHETIC_FEW_SHOT_PREFIX,
    examples=examples,
    suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
    input_variables=["subject","extra"],
    example_prompt=SYNTHETIC_DATA_EXAMPLE,
)

# %%
from os import strerror
class AmazonProductReviews(BaseModel):
    patient_id: int
    patient_name: str
    diagnosis_code: str
    procedure_code: str
    total_charge: str
    insurance_claim_amount: str
    title_x: str
    parent_asin: str
    categories: str
    cat1: str
    cat2: str
    cat3: str
    cat4: str
    cat5: str
    rating: int
    title_y: str
    text: str
    asin: str
    user_id: str
    helpful_vote: int
    verified_purchase: bool
    date: str
    time: str

# %% [markdown]
# # **Creating Data Generator**

# %%
synthetic_data_generator = create_openai_data_generator(
    output_schema=AmazonProductReviews,
    llm=ChatNVIDIA(model="nvidia/nemotron-4-340b-instruct",temperature=0.2),
    prompt=prompt_template
)

# %%
synthetic_results = synthetic_data_generator.generate(
    subject="amazon_product_reviews",
    extra = "the name must be chosen at random. Make it something you wouldn't normally choose.",
    runs=10,
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-29-fa4ae6d9208d> in <cell line: 1>()
# ----> 1 synthetic_results = synthetic_data_generator.generate(
#       2     subject="amazon_product_reviews",
#       3     extra = "the name must be chosen at random. Make it something you wouldn't normally choose.",
#       4     runs=10,
#       5
#
# /usr/local/lib/python3.10/dist-packages/langchain_experimental/tabular_synthetic_data/base.py in generate(self, subject, runs, *args, **kwargs)
#      99             )
#     100         for _ in range(runs):
# --> 101             result = self.llm_chain.run(subject=subject, *args, **kwargs)
#     102             self.results.append(result)
#     103             self._update_examples(result)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     177                 warned = True
#     178                 emit_warning()
# --> 179             return wrapped(*args, **kwargs)
#     180
#     181         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     609
#     610         if kwargs and not args:
# --> 611             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     612                 _output_key
#     613             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     177                 warned = True
#     178                 emit_warning()
# --> 179             return wrapped(*args, **kwargs)
#     180
#     181         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     387         }
#     388
# --> 389         return self.invoke(
#     390             inputs,
#     391             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     168         except BaseException as e:
#     169             run_manager.on_chain_error(e)
# --> 170             raise e
#     171         run_manager.on_chain_end(outputs)
#     172
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     158             self._validate_inputs(inputs)
#     159             outputs = (
# --> 160                 self._call(inputs, run_manager=run_manager)
#     161                 if new_arg_supported
#     162                 else self._call(inputs)
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     124         run_manager: Optional[CallbackManagerForChainRun] = None,
#     125     ) -> Dict[str, str]:
# --> 126         response = self.generate([inputs], run_manager=run_manager)
#     127         return self.create_outputs(response)[0]
#     128
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     136         callbacks = run_manager.get_child() if run_manager else None
#     137         if isinstance(self.llm, BaseLanguageModel):
# --> 138             return self.llm.generate_prompt(
#     139                 prompts,
#     140                 stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     782     ) -> LLMResult:
#     783         prompt_messages = [p.to_messages() for p in prompts]
# --> 784         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     785
#     786     async def agenerate_prompt(
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     639                 if run_managers:
#     640                     run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 641                 raise e
#     642         flattened_outputs = [
#     643             LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     629             try:
#     630                 results.append(
# --> 631                     self._generate_with_cache(
#     632                         m,
#     633                         stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     848         else:
#     849             if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 850                 result = self._generate(
#     851                     messages, stop=stop, run_manager=run_manager, **kwargs
#     852                 )
#
# /usr/local/lib/python3.10/dist-packages/langchain_nvidia_ai_endpoints/chat_models.py in _generate(self, messages, stop, run_manager, **kwargs)
#     379         inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     380         payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 381         response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     382         responses, _ = self._client.postprocess(response)
#     383         self._set_callback_out(responses, run_manager)
#
# /usr/local/lib/python3.10/dist-packages/langchain_nvidia_ai_endpoints/_common.py in get_req(self, payload, extra_headers)
#     451     ) -> Response:
#     452         """Post to the API."""
# --> 453         response, session = self._post(
#     454             self.infer_url, payload, extra_headers=extra_headers
#     455         )
#
# /usr/local/lib/python3.10/dist-packages/langchain_nvidia_ai_endpoints/_common.py in _post(self, invoke_url, payload, extra_headers)
#     347             **self.__add_authorization(self.last_inputs)
#     348         )
# --> 349         self._try_raise(response)
#     350         return response, session
#     351
#
# /usr/local/lib/python3.10/dist-packages/langchain_nvidia_ai_endpoints/_common.py in _try_raise(self, response)
#     440                 body += "\nPlease check or regenerate your API key."
#     441             # todo: raise as an HTTPError
# --> 442             raise Exception(f"{header}\n{body}") from None
#     443
#     444     ###################################################################################
#
# Exception: [500] Internal Server Error
# Inference error
# RequestID: c86aaca0-6264-4ed8-9df4-614a34f5ae05
